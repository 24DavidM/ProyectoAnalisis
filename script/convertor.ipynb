# %%
import pandas as pd
import json

# %%
#PRIMER DATASET
EloRatings = pd.read_csv("../csv/EventosDeportivos/EloRatings.csv")

# %%
#SEGUNDO DATASET
EventosAtleticos = pd.read_csv("../csv/EventosDeportivos/athleticEvents.csv")

# %%
EventosAtleticos
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#TERCER DATASET
WordCup = pd.read_csv("../csv/EventosDeportivos/WorldCups.csv")

# %%
WordCup
# Out:
#    Year;Country;Winner;Runners-Up;Third;Fourth;GoalsScored;QualifiedTeams;MatchesPlayed;Attendance
# 0   1930;Uruguay;Uruguay;Argentina;USA;Yugoslavia;...
# 1   1934;Italy;Italy;Czechoslovakia;Germany;Austri...
# 2   1938;France;Italy;Hungary;Brazil;Sweden;84;15;...
# 3   1950;Brazil;Uruguay;Brazil;Sweden;Spain;88;13;...
# 4   1954;Switzerland;Germany FR;Hungary;Austria;Ur...
# 5   1958;Sweden;Brazil;Sweden;France;Germany FR;12...
# 6   1962;Chile;Brazil;Czechoslovakia;Chile;Yugosla...
# 7   1966;England;England;Germany FR;Portugal;Sovie...
# 8   1970;Mexico;Brazil;Italy;Germany FR;Uruguay;95...
# 9   1974;Germany;Germany FR;Netherlands;Poland;Bra...
# 10  1978;Argentina;Argentina;Netherlands;Brazil;It...
# 11  1982;Spain;Italy;Germany FR;Poland;France;146;...
# 12  1986;Mexico;Argentina;Germany FR;France;Belgiu...
# 13  1990;Italy;Germany FR;Argentina;Italy;England;...
# 14  1994;USA;Brazil;Italy;Sweden;Bulgaria;141;24;5...
# 15  1998;France;France;Brazil;Croatia;Netherlands;...
# ...

# %%
#CUARTO DATASET
WordCupMatches = pd.read_csv("../csv/EventosDeportivos/WorldCupMatch.csv")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[25], line 2
#       1 #CUARTO DATASET
# ----> 2 WordCupMatches = pd.read_csv("../csv/EventosDeportivos/WorldCupMatch.csv")
#
# File ~/.local/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
EloRatingsJS = EloRatings.to_dict(orient="records")

# %%
with open("../json/EventosDeportivos/EloRatings.json", "w", encoding="utf-8") as json_file:
    json.dump(EloRatingsJS, json_file, indent=4, ensure_ascii=False)
