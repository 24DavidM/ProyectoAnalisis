# %%
#MULLO DIEGO 
import pandas as pd

# %%
#PRIMER DATASET
csvDoscientos = r"C:\Users\Usuario\Downloads\200Corona.csv" #Se carga el csv a una variable
data1 = pd.read_csv(csvDoscientos, delimiter=';') # se trasnforma a dataframe
print("CSV convertido a DataFrame")
data1
# Out:
# CSV convertido a DataFrame
#              PostID                                   Post Description  \
# 0       CjvSXTIuZ5_  If you need to be tested for Covid-19 but are ...
# 1       CjvDGdKMrRr  At heal360 Arlington, we are here to provide t...
# 2       CjvItFAoKhM                        Yikes! #covid #covidtesting
# 3       CjwEY8rPmfx  NO-COST COVID-19 TESTING IN WILMINGTON CA\n\n📲...
# 4       Cjv0fphO7wP  #homeburglary \n\n#supicious \n\n#911calls \n\...
# ...             ...                                                ...
# 200149  DAN7BsTuBrG  👀Vacaciones en Argentina, todo lo que tenés qu...
# 200150  DARcSwAB8NH  ✨Care for COVID: Crafting Day Recap🤩🫶\n\nThank...
# 200151  DARz37eIGCX  Feliz día internacional de la enfermería!!! Es...
# 200152  DAQ-rPtRp3D  En cette période de confinement, je vous envoi...
# 200153  DAQ7C3LuZ0w  What Doctors Want You to Know About XEC, the N...
#
#               Date Language Code Full Language Sentiment
# ...

# %%
#SEGUNDO DATASET
csvEquipos = r"C:\Users\Usuario\Downloads\championsequipos.csv" #Se carga el csv a una variable
data2 = pd.read_csv(csvEquipos, delimiter=',') # se trasnforma a dataframe
print("CSV convertido a DataFrame")
data2
# Out:
# CSV convertido a DataFrame
#     team_id      country                        team  \
# 0     50138        Italy    FC Internazionale Milano
# 1     50124        Spain         AtlÃ©tico de Madrid
# 2     50111      Austria               SK Sturm Graz
# 3     52816        Italy                 Atalanta BC
# 4     50050     Scotland                   Celtic FC
# 5     52969        Italy             Bologna FC 1909
# 6     52797     Slovakia       Å K Slovan Bratislava
# 7     50147     Portugal                  SL Benfica
# 8   2602798        Spain                   Girona FC
# 9      7889      England                Liverpool FC
# 10  2603790      Germany                  RB Leipzig
# 11    50107      Germany               VfB Stuttgart
# 12    50033      Czechia             AC Sparta Praha
# 13    50080        Spain                FC Barcelona
# 14    52683      England              Aston Villa FC
# 15    50023       France                   AS Monaco
# ...

# %%
#TERCER DATASET
csvJugadores = r"C:\Users\Usuario\Downloads\championsjugadores.csv" #Se carga el csv a una variable
data3 = pd.read_csv(csvJugadores, delimiter=',') # se trasnforma a dataframe
print("CSV convertido a DataFrame")
data3
# Out:
# CSV convertido a DataFrame
#      id_player         player_name  nationality field_position  \
# 0    250016833          Harry Kane      England        Forward
# 1    250105927    Viktor GyÃ¶keres       Sweden        Forward
# 2    250121533   VinÃ­cius JÃºnior       Brazil        Forward
# 3    250121294   Tijjani Reijnders  Netherlands     Midfielder
# 4    250160436   Maghnes Akliouche       France     Midfielder
# ..         ...                 ...          ...            ...
# 903  250011071          Scott Bain     Scotland     Goalkeeper
# 904  250000104     Carlo Pinsoglio        Italy     Goalkeeper
# 905     108501  Wojciech SzczÄ™sny       Poland     Goalkeeper
# 906     103827  CÃ©sar Azpilicueta        Spain       Defender
# 907     101585        Vito Mannone        Italy     Goalkeeper
#
#                position  weight(kg)  height(cm)  age  id_team  \
# 0               STRIKER        65.0       188.0   31    50037
# ...

# %%
#CUARTO DATASET
csvGoles = r"C:\Users\Usuario\Downloads\championsgoles.csv" #Se carga el csv a una variable
data4 = pd.read_csv(csvGoles, delimiter=',') # se trasnforma a dataframe
print("CSV convertido a DataFrame")
data4
# Out:
# CSV convertido a DataFrame
#      id_player  goals  inside_area  outside_area  right_foot  left_foot  head  \
# 0    250112880    5.0          3.0           2.0         1.0        4.0   0.0
# 1    250139445    3.0          1.0           2.0         2.0        1.0   0.0
# 2    250121533    4.0          3.0           1.0         2.0        2.0   0.0
# 3    250159544    3.0          2.0           1.0         3.0        0.0   0.0
# 4    250091187    3.0          2.0           1.0         2.0        1.0   0.0
# ..         ...    ...          ...           ...         ...        ...   ...
# 903  250011071    NaN          NaN           NaN         NaN        NaN   NaN
# 904  250000104    NaN          NaN           NaN         NaN        NaN   NaN
# 905     108501    NaN          NaN           NaN         NaN        NaN   NaN
# 906     103827    NaN          NaN           NaN         NaN        NaN   NaN
# 907     101585    NaN          NaN           NaN         NaN        NaN   NaN
#
# ...

# %%
#VALORES NULOS EN EL PRIMER DATAFRAME
print("Los valores nulos en el primer dataset son:")
data1.isnull().sum()
# Out:
# Los valores nulos en el primer dataset son:
# PostID              0
# Post Description    0
# Date                0
# Language Code       0
# Full Language       0
# Sentiment           0
# dtype: int64

# %%
print("Los valores nulos en el segundo dataset son:")
data2.isnull().sum()
# Out:
# Los valores nulos en el segundo dataset son:
# team_id    0
# country    0
# team       0
# logo       0
# dtype: int64

# %%
print("Los valores nulos en el tercer dataset son:")
data3.isnull().sum()
# Out:
# Los valores nulos en el tercer dataset son:
# id_player           0
# player_name         0
# nationality         0
# field_position      0
# position          207
# weight(kg)        754
# height(cm)        729
# age                 0
# id_team             0
# player_image        0
# dtype: int64

# %%
print("Los valores nulos en el cuarto dataset son:")
data4.isnull().sum()
# Out:
# Los valores nulos en el cuarto dataset son:
# id_player             0
# goals               181
# inside_area         181
# outside_area        181
# right_foot          181
# left_foot           181
# head                181
# other               181
# penalties_scored    181
# dtype: int64

# %%
#Limpieza de datos nulos DATASET 3
data3 = data3.dropna()
print("DATASET 3:")
data3.isnull().sum()
# Out:
# DATASET 3:
# id_player         0
# player_name       0
# nationality       0
# field_position    0
# position          0
# weight(kg)        0
# height(cm)        0
# age               0
# id_team           0
# player_image      0
# dtype: int64

# %%
#DATASET 4 
data4 = data4.dropna()
print("DATASET 4")
data4.isnull().sum()
# Out:
# DATASET 4
# id_player           0
# goals               0
# inside_area         0
# outside_area        0
# right_foot          0
# left_foot           0
# head                0
# other               0
# penalties_scored    0
# dtype: int64

# %%
#PASAMOS EL PRIMER DATAFRAME A BASE RELACIONAL MYSQL WORKBENCH
import sqlalchemy
from sqlalchemy import create_engine
usuario = 'root'
contrasenia = '123456'
host = 'localhost'
puerto = '3306'
base_de_datos = 'base_no_relacional'

# %%
# Conexion a MYSQL
connection_string = f'mysql+mysqlconnector://{usuario}:{contrasenia}@{host}:{puerto}/{base_de_datos}'
engine = create_engine(connection_string)

# %%
batch_size = 5000

try:

    with engine.begin() as connection:
   
        for start in range(0, len(data1), batch_size):
            batch = data1.iloc[start:start + batch_size]
            try:
                # Insertar el lote en la base de datos
                batch.to_sql('dosk_registros', con=connection, index=False, if_exists='append') 
                print(f"Lote {start // batch_size + 1} insertado exitosamente.")
            except Exception as e:
                print(f"Error al insertar el lote {start // batch_size + 1}: {e}")
                connection.rollback()
                break
except Exception as e:
    print(f"Error de conexión o transacción: {e}")
finally:
    engine.dispose()
# Out:
# Lote 1 insertado exitosamente.
# Lote 2 insertado exitosamente.
# Lote 3 insertado exitosamente.
# Lote 4 insertado exitosamente.
# Lote 5 insertado exitosamente.
# Lote 6 insertado exitosamente.
# Lote 7 insertado exitosamente.
# Lote 8 insertado exitosamente.
# Lote 9 insertado exitosamente.
# Lote 10 insertado exitosamente.
# Lote 11 insertado exitosamente.
# Lote 12 insertado exitosamente.
# Lote 13 insertado exitosamente.
# Lote 14 insertado exitosamente.
# Lote 15 insertado exitosamente.
# Lote 16 insertado exitosamente.
# Lote 17 insertado exitosamente.
# Lote 18 insertado exitosamente.
# Lote 19 insertado exitosamente.
# Lote 20 insertado exitosamente.
# Lote 21 insertado exitosamente.
# Lote 22 insertado exitosamente.
# Lote 23 insertado exitosamente.
# Lote 24 insertado exitosamente.
# Lote 25 insertado exitosamente.
# Lote 26 insertado exitosamente.
# Lote 27 insertado exitosamente.
# Lote 28 insertado exitosamente.
# Lote 29 insertado exitosamente.
# ...

# %%
#Se establece la conexion pero para la nueva base de datos
usuario = 'root'
contrasenia = '123456'
host = 'localhost'
puerto = '3306'
base_de_datos = 'champions'

# Crear la cadena de conexión y el engine
connection_string = f'mysql+mysqlconnector://{usuario}:{contrasenia}@{host}:{puerto}/{base_de_datos}?connect_timeout=300'
engine = create_engine(connection_string)

data3 = data3.copy()
data3.rename(columns={"weight(kg)": "weight_kg", "height(cm)": "height_cm"}, inplace=True)

# %%
#Ahora insertaremos los datos relacionados a mysql
with engine.begin() as connection:
    try:
        # Insertar en la tabla equipos
        data2.to_sql('equipos', con=connection, index=False, if_exists='append')
        # Luego insertar en jugadores
        data3.to_sql('jugadores', con=connection, index=False, if_exists='append')
        # Finalmente insertar en goles
        data4.to_sql('goles', con=connection, index=False, if_exists='append')

        print("DataFrames insertados exitosamente.")
    except Exception as e:
        print(f"Error durante la operación de la base de datos: {e}")
# Out:
# Error durante la operación de la base de datos: (mysql.connector.errors.ProgrammingError) 1054 (42S22): Unknown column 'id_player' in 'field list'
# [SQL: INSERT INTO goles (id_player, goals, inside_area, outside_area, right_foot, left_foot, head, other, penalties_scored) VALUES (%(id_player)s, %(goals)s, %(inside_area)s, %(outside_area)s, %(right_foot)s, %(left_foot)s, %(head)s, %(other)s, %(penalties_scored)s)]
# ...

# %%
#Ahora insertaremos el primer data ser a MongoDB
from pymongo import MongoClient, WriteConcern
import json

# %%
mongo_url = 'mongodb://localhost:27017'
try:
    client = MongoClient(mongo_url)
    db = client["proyecto"]
    print("Conexión exitosa a MongoDB")
except Exception as e:
    print(f"Error de conexión: {e}")
# Out:
# Conexión exitosa a MongoDB

# %%
db = client['proyecto']
collection = db['200k_registros']
data_dict = data1.to_dict(orient="records")

# %%
batch_size = 5000

for i in range(0, len(data_dict), batch_size):
    batch = data_dict[i:i + batch_size]
    try:
        collection.insert_many(batch)
        print(f"Lote {i // batch_size + 1} insertado exitosamente.")
    except Exception as e:
        print(f"Error al insertar lote {i // batch_size + 1}: {e}")

print("Proceso de inserción completado.")
# Out:
# Lote 1 insertado exitosamente.
# Lote 2 insertado exitosamente.
# Lote 3 insertado exitosamente.
# Lote 4 insertado exitosamente.
# Lote 5 insertado exitosamente.
# Lote 6 insertado exitosamente.
# Lote 7 insertado exitosamente.
# Lote 8 insertado exitosamente.
# Lote 9 insertado exitosamente.
# Lote 10 insertado exitosamente.
# Lote 11 insertado exitosamente.
# Lote 12 insertado exitosamente.
# Lote 13 insertado exitosamente.
# Lote 14 insertado exitosamente.
# Lote 15 insertado exitosamente.
# Lote 16 insertado exitosamente.
# Lote 17 insertado exitosamente.
# Lote 18 insertado exitosamente.
# Lote 19 insertado exitosamente.
# Lote 20 insertado exitosamente.
# Lote 21 insertado exitosamente.
# Lote 22 insertado exitosamente.
# Lote 23 insertado exitosamente.
# Lote 24 insertado exitosamente.
# Lote 25 insertado exitosamente.
# Lote 26 insertado exitosamente.
# Lote 27 insertado exitosamente.
# Lote 28 insertado exitosamente.
# Lote 29 insertado exitosamente.
# ...

# %%
#Transformar de csv a json
data1.to_json('data1_json.json', orient='records')

# %%
data2.to_json('data2_sjon.json',orient='records')

# %%
data3.to_json('data3_sjon.json',orient='records')

# %%
data4.to_json('data4_sjon.json',orient='records')

# %%
#Trasnformar de json a csv
data1_csv = pd.read_json('data1_json.json', orient='records', lines=True)
data1_csv.to_csv('data1_csv.csv', index=False)

# %%
data2_csv = pd.read_json('data2_sjon.json', orient='records', lines=True)
data2_csv.to_csv('data2_csv.csv', index=False)

# %%
data3_csv = pd.read_json('data3_sjon.json', orient='records', lines=True)
data3_csv.to_csv('data3_csv.csv', index=False)

# %%
data4_csv = pd.read_json('data4_sjon.json', orient='records', lines=True)
data4_csv.to_csv('data4_csv.csv', index=False)

# %%
#Vamos a crear otra conexion para guardar los registros del dataframe en la nube
from pymongo import MongoClient

# %%
client = MongoClient("mongodb+srv://example:12345@cluster0.cxjls.mongodb.net/")
db = client["diego"]
collection = db["equipos"]
data2_dict = data2.to_dict(orient='records')
collection.insert_many(data2_dict)
# Out:
# InsertManyResult([ObjectId('679add404f0520fab11e4ce7'), ObjectId('679add404f0520fab11e4ce8'), ObjectId('679add404f0520fab11e4ce9'), ObjectId('679add404f0520fab11e4cea'), ObjectId('679add404f0520fab11e4ceb'), ObjectId('679add404f0520fab11e4cec'), ObjectId('679add404f0520fab11e4ced'), ObjectId('679add404f0520fab11e4cee'), ObjectId('679add404f0520fab11e4cef'), ObjectId('679add404f0520fab11e4cf0'), ObjectId('679add404f0520fab11e4cf1'), ObjectId('679add404f0520fab11e4cf2'), ObjectId('679add404f0520fab11e4cf3'), ObjectId('679add404f0520fab11e4cf4'), ObjectId('679add404f0520fab11e4cf5'), ObjectId('679add404f0520fab11e4cf6'), ObjectId('679add404f0520fab11e4cf7'), ObjectId('679add404f0520fab11e4cf8'), ObjectId('679add404f0520fab11e4cf9'), ObjectId('679add404f0520fab11e4cfa'), ObjectId('679add404f0520fab11e4cfb'), ObjectId('679add404f0520fab11e4cfc'), ObjectId('679add404f0520fab11e4cfd'), ObjectId('679add404f0520fab11e4cfe'), ObjectId('679add404f0520fab11e4cff'), ObjectId('679add404f0520fab11e
# ...

# %%
#dataset 3 a mongo
client = MongoClient("mongodb+srv://example:12345@cluster0.cxjls.mongodb.net/")
db = client["diego"]
collection = db["jugadores"]
data3_dict = data3.to_dict(orient='records')
collection.insert_many(data3_dict)
# Out:
# InsertManyResult([ObjectId('679adfa94f0520fab11e5011'), ObjectId('679adfa94f0520fab11e5012'), ObjectId('679adfa94f0520fab11e5013'), ObjectId('679adfa94f0520fab11e5014'), ObjectId('679adfa94f0520fab11e5015'), ObjectId('679adfa94f0520fab11e5016'), ObjectId('679adfa94f0520fab11e5017'), ObjectId('679adfa94f0520fab11e5018'), ObjectId('679adfa94f0520fab11e5019'), ObjectId('679adfa94f0520fab11e501a'), ObjectId('679adfa94f0520fab11e501b'), ObjectId('679adfa94f0520fab11e501c'), ObjectId('679adfa94f0520fab11e501d'), ObjectId('679adfa94f0520fab11e501e'), ObjectId('679adfa94f0520fab11e501f'), ObjectId('679adfa94f0520fab11e5020'), ObjectId('679adfa94f0520fab11e5021'), ObjectId('679adfa94f0520fab11e5022'), ObjectId('679adfa94f0520fab11e5023'), ObjectId('679adfa94f0520fab11e5024'), ObjectId('679adfa94f0520fab11e5025'), ObjectId('679adfa94f0520fab11e5026'), ObjectId('679adfa94f0520fab11e5027'), ObjectId('679adfa94f0520fab11e5028'), ObjectId('679adfa94f0520fab11e5029'), ObjectId('679adfa94f0520fab11e
# ...

# %%
#dataset 4 a mongo 
client = MongoClient("mongodb+srv://example:12345@cluster0.cxjls.mongodb.net/")
db = client["diego"]
collection = db["goles"]
data4_dict = data4.to_dict(orient='records')
collection.insert_many(data4_dict)
# Out:
# InsertManyResult([ObjectId('679adfb84f0520fab11e50ac'), ObjectId('679adfb84f0520fab11e50ad'), ObjectId('679adfb84f0520fab11e50ae'), ObjectId('679adfb84f0520fab11e50af'), ObjectId('679adfb84f0520fab11e50b0'), ObjectId('679adfb84f0520fab11e50b1'), ObjectId('679adfb84f0520fab11e50b2'), ObjectId('679adfb84f0520fab11e50b3'), ObjectId('679adfb84f0520fab11e50b4'), ObjectId('679adfb84f0520fab11e50b5'), ObjectId('679adfb84f0520fab11e50b6'), ObjectId('679adfb84f0520fab11e50b7'), ObjectId('679adfb84f0520fab11e50b8'), ObjectId('679adfb84f0520fab11e50b9'), ObjectId('679adfb84f0520fab11e50ba'), ObjectId('679adfb84f0520fab11e50bb'), ObjectId('679adfb84f0520fab11e50bc'), ObjectId('679adfb84f0520fab11e50bd'), ObjectId('679adfb84f0520fab11e50be'), ObjectId('679adfb84f0520fab11e50bf'), ObjectId('679adfb84f0520fab11e50c0'), ObjectId('679adfb84f0520fab11e50c1'), ObjectId('679adfb84f0520fab11e50c2'), ObjectId('679adfb84f0520fab11e50c3'), ObjectId('679adfb84f0520fab11e50c4'), ObjectId('679adfb84f0520fab11e
# ...
